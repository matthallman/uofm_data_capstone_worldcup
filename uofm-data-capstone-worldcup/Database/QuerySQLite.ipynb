# %%
from sqlalchemy import create_engine, inspect

import sqlalchemy
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt

# %%
database_path = "worldcupdb.sqlite"
conn_string = f"sqlite:///{database_path}"

# Create an engine that can talk to the database
engine = create_engine(conn_string)

# %%
# get all tables
inspector_gadget = inspect(engine)
tables = inspector_gadget.get_table_names()
for table in tables:
    print(table)
    
    # get all columns in table
    columns = inspector_gadget.get_columns(table)
    for column in columns:
        print(column)
    print()
# Out:
# sqlitedb
# {'name': 'index', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Match', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Group', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Stage', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S2%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_Prob', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_wins', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Simulation', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'MatchWinner', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
#
# worldcupdb
# {'name': 'index', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Match', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Groups', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Stage', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S2%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_Prob', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_wins', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Simulation', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'MatchWinner', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
#
# worldcupdb1
# {'name': 'index', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Match', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Group', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Stage', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S2%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_Prob', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_wins', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Simulation', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'MatchWinner', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
#
# worldcupdb2
# {'name': 'index', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Match', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Group', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Stage', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S2%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_Prob', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_wins', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Simulation', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'MatchWinner', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
#
# worldcupdbtest
# {'name': 'index', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Match', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Key', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Group', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Stage', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad1Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S2%', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Squad2Seed', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_Prob', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'S1_wins', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'Simulation', 'type': BIGINT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'MatchWinner', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}

# %%
group = '"R8", "R16", "Semis", "Finals"'
team1 = '"France", "Tunisia", "Australia", "Poland", "Denmark", "Argentina","Saudi Arabia", "Mexico", "Senegal", "Ecuador", "Netherlands", "Qatar", "England", "Portugal", "Germany", "Iran", "South Korea", "Morocco", "Belgium", "Japan", "Brazil", "Switzerland", "Cameroon", "Spain", "Croatia", "Canada", "Serbia", "Costa Rica"'
con = engine.connect()

query = f"""
        SELECT
            *
        FROM
            worldcupdb
        WHERE
            Squad1 = 'United States'
            AND Squad2 in ({team1})
            AND Groups in ({group})
        """
print(query)
testdf2 = pd.read_sql(query, con)
testdf2.head()
# Out:
#         SELECT
#             *
#         FROM
#             worldcupdb
#         WHERE
#             Squad1 = 'United States'
#             AND Squad2 in ("France", "Tunisia", "Australia", "Poland", "Denmark", "Argentina","Saudi Arabia", "Mexico", "Senegal", "Ecuador", "Netherlands", "Qatar", "England", "Portugal", "Germany", "Iran", "South Korea", "Morocco", "Belgium", "Japan", "Brazil", "Switzerland", "Cameroon", "Spain", "Croatia", "Canada", "Serbia", "Costa Rica")
#             AND Groups in ("R8", "R16", "Semis", "Finals")
#    index  Match       Squad1Key       Squad2Key Groups     Stage  \
# 0      0     60  Knockout Round  Knockout Round     R8  Knockout
# 1      1     58  Knockout Round  Knockout Round     R8  Knockout
# 2      2     60  Knockout Round  Knockout Round     R8  Knockout
# 3      3     58  Knockout Round  Knockout Round     R8  Knockout
# 4      4     60  Knockout Round  Knockout Round     R8  Knockout
#
#           Squad1       S1% Squad1Seed     Squad2       S2% Squad2Seed  \
# 0  United States  0.683675        M52     France  0.780360        M51
# 1  United States  0.683675        M49    Tunisia  0.649053        M50
# 2  United States  0.683675        M52     France  0.780360        M51
# 3  United States  0.683675        M49  Australia  0.669404        M50
# 4  United States  0.683675        M52    Tunisia  0.649053        M51
#
#     S1_Prob  S1_wins  Simulation    MatchWinner
# 0  0.378233        1           6  United States
# 1  0.538880        1          24  United States
# 2  0.378233        1          29  United States
# 3  0.516300        1          46  United States
# 4  0.538880        1          47  United States
