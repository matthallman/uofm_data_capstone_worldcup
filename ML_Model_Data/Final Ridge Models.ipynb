# %%
import numpy as np
import pandas as pd
from sklearn import *
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

#Initial CSV Read

xGS_Total = pd.read_csv(r'CSVs\International\Int_xGS_Total.csv' ,encoding='latin-1')
xGA_Total = pd.read_csv(r'CSVs\International\Int_xGA_Total.csv' ,encoding='latin-1')

# loading linear algorithms
from sklearn.linear_model import LinearRegression, ElasticNet, Lasso, Ridge

# machine learning processing and metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Evaluate Model function

def evaluateModel(model, X_train, y_train, X_test, y_test):
    # FIT THE MODEL
    model.fit(X_train, y_train)

    # EVALUATE the MODEL
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)

    # PRINT the METRICS
    print("TRAINING SET")

    # Score the prediction with MSE and R2
    mse_train = np.sqrt(mean_squared_error(y_train, train_preds))
    r2_train = r2_score(y_train, train_preds)
    mae_train = mean_absolute_error(y_train, train_preds)

    print(f"root mean squared error (RMSE): {mse_train}")
    print(f"R-squared (R2 ): {r2_train}")
    print(f"MAE {mae_train}")

    print()

    # PRINT the METRICS
    print("Testing SET")

    # Score the prediction with MSE and R2
    mse_test = np.sqrt(mean_squared_error(y_test, test_preds))
    r2_test = r2_score(y_test, test_preds)
    mae_test = mean_absolute_error(y_test, test_preds)

    print(f"root mean squared error (RMSE): {mse_test}")
    print(f"R-squared (R2 ): {r2_test}")
    print(f"MAE {mae_test}")
    
    plt.figure(figsize=(10,6))
    plt.scatter(y_test, test_preds)
    plt.title("Actual vs Predicted Plot")
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.plot(y_test, y_test)
    plt.show()
    
    # Plot Residuals
    plt.figure(figsize=(10,6))
    plt.scatter(test_preds, test_preds - y_test)
    plt.hlines(y=0, xmin=test_preds.min(), xmax=test_preds.max(), color="r")
    plt.title("Residuals")
    plt.xlabel("Prediction")
    plt.ylabel("Error")
    plt.show()

    return(model)

# %%
#Model Prep

 
xGS_Column_Drop_List = ['Key','Year','Competition','Squad','Age','MP','G/SoT','TklW','O. TklW','G/Sh']
xGA_Column_Drop_List = ['Key','Year','Competition','Squad','O. Age','O. MP','O. G/SoT','O. Fld', 'O. TklW', 'TklW','O. G/Sh']

xGS_Model = xGS_Total.drop(xGS_Column_Drop_List, axis=1)
xGA_Model = xGA_Total.drop(xGA_Column_Drop_List, axis=1)

xGS_Model_features = xGS_Model.drop(['Confederation','Gls'], axis=1)
xGA_Model_features = xGA_Model.drop(['Confederation','O. Gls'], axis=1)

xGS_scaler = StandardScaler().fit(xGS_Model_features)
xGA_scaler = StandardScaler().fit(xGA_Model_features)


xGS_scaler_df = pd.DataFrame(xGS_scaler.transform(xGS_Model_features), columns = xGS_Model_features.columns)
xGA_scaler_df = pd.DataFrame(xGA_scaler.transform(xGA_Model_features), columns = xGA_Model_features.columns)

xGS_scaler_df['Gls'] = xGS_Model['Gls']
xGA_scaler_df['O. Gls'] = xGA_Model['O. Gls']
xGS_scaler_df['Confederation'] = xGS_Model['Confederation']
xGA_scaler_df['Confederation'] = xGA_Model['Confederation']

# %%
# Create final model variable and one-hot encode Confederation

xGS_Model_Final = pd.get_dummies(xGS_scaler_df, columns=['Confederation'])
xGA_Model_Final = pd.get_dummies(xGA_scaler_df, columns=['Confederation'])

# %%
# Get features and target for both models

xGS_X = xGS_Model_Final.drop('Gls', axis=1).values
xGS_y = xGS_Model_Final['Gls'].values

xGA_X = xGA_Model_Final.drop('O. Gls', axis=1).values
xGA_y = xGA_Model_Final['O. Gls'].values

# %%
# Use the Sklearn `train_test_split()` function to split the data into training and testing data
xGS_X_train, xGS_X_test, xGS_y_train, xGS_y_test = train_test_split(xGS_X, xGS_y, random_state=42, test_size=.2)


xGA_X_train, xGA_X_test, xGA_y_train, xGA_y_test = train_test_split(xGA_X, xGA_y, random_state=42, test_size=.2)

# %%
ridge1 = Ridge()
ridge2 = Ridge()
x_GS_ridge = ridge1.fit(xGS_X, xGS_y)
x_GA_ridge = ridge2.fit(xGA_X, xGA_y)

# %%
x_GS_preds = x_GS_ridge.predict(xGS_X)
x_GA_preds = x_GA_ridge.predict(xGA_X)

# %%
xGS_Total.drop('xGA', axis=1, inplace=True)

# %%
xGS_Total['xGS'] = x_GS_preds
xGA_Total['xGA'] = x_GA_preds

# %%
xGS_Total.loc[xGS_Total['Squad']=='United States']
# Out:
#                                  Key  Year   Competition          Squad   Age  \
# 242  2016-Copa America-United States  2016  Copa America  United States  28.2
# 243      2021-Gold Cup-United States  2021      Gold Cup  United States  23.8
# 244      2019-Gold Cup-United States  2019      Gold Cup  United States  25.2
# 245      2017-Gold Cup-United States  2017      Gold Cup  United States  27.6
#
#      Poss   Gls     Sh   SoT  SoT%  ...  CrdY  CrdR   Fld    Int   TklW  \
# 242  42.0  1.17   8.67  2.50  28.8  ...  1.33  0.17  12.8  12.50  12.00
# 243  56.0  1.59  11.40  5.08  44.4  ...  0.63  0.00  12.2   9.84   7.78
# 244  55.0  2.50  15.30  6.00  39.1  ...  0.17  0.00  11.2   7.17   9.83
# 245  59.5  2.17  14.30  7.50  52.3  ...  0.33  0.00  17.3  12.70  11.70
#
#      Confederation  O. CrdY  O. TklW MP       xGS
# 242       CONCACAF     1.67     11.7  6  0.649485
# 243       CONCACAF     1.27     10.3  6  1.527840
# 244       CONCACAF     1.50     10.3  6  1.780832
# 245       CONCACAF     2.00     13.5  6  2.498949
#
# [4 rows x 23 columns]

# %%
xGA_Total.loc[xGA_Total['Squad']=='Morocco']
# Out:
#                                     Key  Year            Competition    Squad  \
# 180              2018-World Cup-Morocco  2018              World Cup  Morocco
# 181  2021-Africa Cup of Nations-Morocco  2021  Africa Cup of Nations  Morocco
# 182  2019-Africa Cup of Nations-Morocco  2019  Africa Cup of Nations  Morocco
# 183  2017-Africa Cup of Nations-Morocco  2017  Africa Cup of Nations  Morocco
#
#      O. Age  O. Poss  O. MP  O. Gls  O. Sh  O. SoT  O. SoT%  O. G/Sh  \
# 180    28.1     51.0      3    1.00  12.70    2.33     18.4     0.08
# 181    26.6     39.4      5    0.75   7.74    2.26     29.3     0.10
# 182    27.6     38.8      4    0.23   3.72    0.70     18.8     0.06
# 183    27.4     51.0      4    0.75   8.25    3.50     42.4     0.09
#
#      O. G/SoT  O. PKatt  O. CrdY  O. CrdR  O. Fld  O. Int Confederation  \
# 180      0.43       0.0     1.33     0.00    20.0    8.00           CAF
# 181      0.33       0.0     2.45     0.00    14.7    7.55           CAF
# 182      0.33       0.0     2.09     0.23    13.7    9.07           CAF
# 183      0.21       0.0     2.00     0.25    23.5   13.50           CAF
#
#      O. TklW  CrdY   TklW       xGA
# 180    10.00  2.67   9.33  0.624803
# 181     7.55  1.13  10.40  0.519608
# 182     8.37  0.23  12.60  0.316543
# 183     9.75  0.00  15.00  0.809253

# %%
World_Cup_Teams = pd.read_csv(r'CSVs\World_Cup_Teams.csv' ,encoding='latin-1')

# %%
World_Cup_Teams = pd.merge(World_Cup_Teams,xGS_Total[['Key','xGS']], on='Key', how='inner')

# %%
# 16          2022-CONMEBOL WCQ-Argentina     C  1.501900  0.745250
# 17            2022-CONMEBOL WCQ-Ecuador     A  1.180177  0.968837
# 18            2022-CONMEBOL WCQ-Uruguay     H  1.160191  1.265821
# 19                2022-UEFA WCQ-Germany     E  3.075068  0.528228
# 20                2022-UEFA WCQ-Denmark     D  2.365264  0.547195
# 21                2022-UEFA WCQ-Belgium     F  2.462967  0.869987
# 22                 2022-UEFA WCQ-France     D  1.999248  0.565788
# 23                2022-UEFA WCQ-Croatia     F  2.081144  0.637629
# 24                  2022-UEFA WCQ-Spain     E  1.735675  0.477421
# 25                 2022-UEFA WCQ-Serbia     G  2.124590  0.742598
# 26                2022-UEFA WCQ-England     B  2.744588  0.333253
# 27            2022-UEFA WCQ-Switzerland     G  1.998269  0.778344
# 28            2022-UEFA WCQ-Netherlands     A  3.142304  0.463511
# 29               2022-UEFA WCQ-Portugal     H  2.344275  0.729315
# 30                 2022-UEFA WCQ-Poland     C  1.892515  0.877613
# 31                  2022-UEFA WCQ-Wales     B  1.457338  1.058736

# %%
Squad_Predicted_Values = World_Cup_Teams[['Squad','Group','xGS','xGA']].copy()

# %%
Squad_Predicted_Values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Squad   32 non-null     object
#  1   Group   32 non-null     object
#  2   xGS     32 non-null     float64
#  3   xGA     32 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB

# %%
Squad_Predicted_Values['% of Points Taken'] = (np.power(Squad_Predicted_Values['xGS'],1.2))/((np.power(Squad_Predicted_Values['xGS'],1.2)) + (np.power(Squad_Predicted_Values['xGA'],1.2)))

# %%
Squad_Predicted_Values
# Out:
#             Squad Group       xGS       xGA  % of Points Taken
# 0           Qatar     A  1.958577  1.181700           0.647100
# 1            Iran     B  1.520378  0.784702           0.688624
# 2     South Korea     H  1.476150  0.593052           0.749189
# 3           Japan     E  1.805929  0.765247           0.736985
# 4    Saudi Arabia     C  1.176455  0.711999           0.646256
# 5       Australia     D  1.746810  0.985206           0.665352
# 6           Ghana     H  0.939300  0.778277           0.556178
# 7         Senegal     A  1.315233  0.579346           0.727870
# 8         Tunisia     D  1.419231  0.679135           0.707746
# 9        Cameroon     G  1.506329  0.901070           0.649449
# 10        Morocco     F  1.821263  0.519608           0.818327
# 11         Canada     F  1.003689  1.331959           0.415916
# 12         Mexico     C  1.769009  0.630572           0.775191
# 13  United States     B  1.527840  1.011575           0.621240
# 14     Costa Rica     E  0.628433  0.982702           0.369004
# 15         Brazil     G  1.996433  0.564112           0.820043
# 16      Argentina     C  1.501900  0.745250           0.698659
# 17        Ecuador     A  1.180177  0.968837           0.558922
# 18        Uruguay     H  1.160191  1.265821           0.473883
# 19        Germany     E  3.075068  0.528228           0.892244
# 20        Denmark     D  2.365264  0.547195           0.852784
# 21        Belgium     F  2.462967  0.869987           0.777087
# 22         France     D  1.999248  0.565788           0.819767
# 23        Croatia     F  2.081144  0.637629           0.805260
# 24          Spain     E  1.735675  0.477421           0.824755
# 25         Serbia     G  2.124590  0.742598           0.779269
# 26        England     B  2.744588  0.333253           0.926231
# 27    Switzerland     G  1.998269  0.778344           0.756105
# 28    Netherlands     A  3.142304  0.463511           0.908600
# 29       Portugal     H  2.344275  0.729315           0.802366
# 30         Poland     C  1.892515  0.877613           0.715479
# 31          Wales     B  1.457338  1.058736           0.594703

# %%
Squad_Predicted_Values.drop(['Test'],axis=1,inplace=True)
